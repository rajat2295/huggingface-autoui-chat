# %%
# !pip3 install transformers
# !pip3 install huggingfacehub
# !pip3 install torch
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement huggingfacehub (from versions: none)
# ERROR: No matching distribution found for huggingfacehub
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 121.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 97.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 59.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 6.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 54.9 MB/s eta 0:00:00
# ...

# %%
# !pip3 install accelerate

# %%
import os
os.environ["HF_TOKEN"]="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"
os.environ["HUGGINGFACEHUB_API_TOKEN"]="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"

# %%
import transformers
import torch

model_id="Rajat1327/Llama-2-7b-chat-ui-finetune"
pipeline = transformers.pipeline("text-generation",model=model_id,model_kwargs={"torch_dtype":torch.bfloat16}, device_map="auto")

pipeline("Hey, build me a header bar")
# Out:
# config.json:   0%|          | 0.00/712 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# Fetching 3 files:   0%|          | 0/3 [00:00<?, ?it/s]
# model-00001-of-00003.safetensors:   0%|          | 0.00/4.94G [00:00<?, ?B/s]
# model-00002-of-00003.safetensors:   0%|          | 0.00/4.95G [00:00<?, ?B/s]
# model-00003-of-00003.safetensors:   0%|          | 0.00/3.59G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/195 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.06k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/21.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/434 [00:00<?, ?B/s]
# Device set to use cuda:0
# ...

# %%
pipeline("make me a portfolio page for a freelancer")
# Out:
# [{'generated_text': 'make me a portfolio page for a freelancer.\n\nThe portfolio page should include:\n\n1. A header with the freelancer\'s name and a logo\n2. A section for showcasing recent projects\n3. A section for showcasing past projects\n4. A section for showcasing skills and expertise\n5. A section for contact information and social media links\n\nThe design should be clean and modern, with a consistent color scheme and font style. The layout should be easy to navigate and visually appealing.\n\nThe freelancer\'s name is "John Doe" and the logo is a simple icon of a laptop. The recent projects section should include 3 projects with images and descriptions. The past projects section should include 5 projects with images and descriptions. The skills and expertise section should include 5 skills with descriptions. The contact information section should include a contact form and email address.\n\nThe freelancer is a web developer and the skills and expertise section should highl
# ...
